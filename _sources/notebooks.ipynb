# %% [markdown]
# # Menghitung Jarak (Tugas 1)

# %% [markdown]
# ### Persiapan

# %% [markdown]
# #### Import Modul

# %%
import pandas as pd
import numpy as np
import math

# %%
df = pd.read_csv("https://raw.githubusercontent.com/FajarFatha/datamining/main/ds_salaries.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %% [markdown]
# ### Proximity Measure for Nominal Attributes

# %%
def d1(i,j):
    P = 8
    M = 0
    for col in ["work_year", "experience_level", "employment_type","job_title","salary_currency","employee_residence","company_location","company_size"]:
        if df[col][i] == df[col][j]:
            M += 1

    return (P-M)/P

# %%
print(d1(1,2))
print(d1(1,3))
print(d1(1,4))
# Out:
# 0.625
# 0.5
# 0.5

# %% [markdown]
# ### Distance on Numeric Data: Minkowski Distance

# %%
def d2(i,j, h):
    result = 0
    for col in ["salary", "salary_in_usd","remote_ratio"]:
        result = math.pow(abs(df[col][i] - df[col][j]), h)
    return result**(1/h)

# %% [markdown]
# Manhattan distance

# %%
print(d2(1,2,1))
print(d2(1,3,1))
print(d2(1,4,1))
# Out:
# 50.0
# 0.0
# 50.0

# %% [markdown]
# Euclidean distance

# %%
print(d2(1,2,2))
print(d2(1,3,2))
print(d2(1,4,2))
# Out:
# 50.0
# 0.0
# 50.0

# %% [markdown]
# ### Dissimiliarity

# %% [markdown]
# d(1,2)

# %%
print(d1(1,2)+d2(1,2,1))
# Out:
# 50.625

# %% [markdown]
# d(1,3)

# %%
print(d1(1,3)+d2(1,3,1))
# Out:
# 0.5

# %% [markdown]
# d(1,4)

# %%
print(d1(1,4)+d2(1,4,1))
# Out:
# 50.5
